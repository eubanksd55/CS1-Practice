# %% [markdown]
# ## Analyzing Health Nutrition & Population Statistics Compiled by the World Bank
# ### Dustin Eubanks
# ___

# %% [markdown]
# Import Pandas, Numpy, Matplotlib, and our original dataset:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/data.csv')

# %% [markdown]
# <br></br>
# ### Initial Analysis
# <br></br>
# Use `.shape`, `.columns`, and `.index.values` to take a look at the rows and columns we have available:

# %%
print(f'Shape: {df.shape}', '\n')

print(f'Columns: {df.columns}', '\n')

print(f'Index: {df.index.values}')
# Out:
# Shape: (89010, 61)
#
# Columns: Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', 'Unnamed: 60'],
#       dtype='object')
#
# Index: [    0     1     2 ... 89007 89008 89009]

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>
# Look at the `.info()`:

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89010 entries, 0 to 89009
# Data columns (total 61 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    89010 non-null  object
#  1   Country Code    89010 non-null  object
#  2   Indicator Name  89010 non-null  object
#  3   Indicator Code  89010 non-null  object
#  4   1960            35482 non-null  float64
#  5   1961            35325 non-null  float64
#  6   1962            35889 non-null  float64
#  7   1963            35452 non-null  float64
#  8   1964            35483 non-null  float64
#  9   1965            35603 non-null  float64
#  10  1966            35538 non-null  float64
#  11  1967            36022 non-null  float64
#  12  1968            35577 non-null  float64
#  13  1969            35630 non-null  float64
#  14  1970            36910 non-null  float64
#  15  1971            37578 non-null  float64
#  16  1972            38015 non-null  float64
#  17  1973            37542 non-null  float64
#  18  1974            37574 non-null  float64
#  19  1975            37760 non-null  float64
#  20  1976            37778 non-null  float64
#  21  1977            38204 non-null  float64
#  22  1978            37797 non-null  float64
#  23  1979            37848 non-null  float64
#  24  1980            38578 non-null  float64
#  25  1981            38829 non-null  float64
#  26  1982            39182 non-null  float64
#  27  1983            38772 non-null  float64
#  28  1984            38964 non-null  float64
#  29  1985            39020 non-null  float64
#  30  1986            39367 non-null  float64
#  31  1987            39832 non-null  float64
#  32  1988            39166 non-null  float64
#  33  1989            39282 non-null  float64
#  34  1990            47722 non-null  float64
#  35  1991            47231 non-null  float64
#  36  1992            47923 non-null  float64
#  37  1993            47398 non-null  float64
#  38  1994            47678 non-null  float64
#  39  1995            51326 non-null  float64
#  40  1996            51386 non-null  float64
#  41  1997            51560 non-null  float64
#  42  1998            51404 non-null  float64
#  43  1999            52442 non-null  float64
#  44  2000            56672 non-null  float64
#  45  2001            52924 non-null  float64
#  46  2002            53536 non-null  float64
#  47  2003            53013 non-null  float64
#  48  2004            53417 non-null  float64
#  49  2005            54304 non-null  float64
#  50  2006            54398 non-null  float64
#  51  2007            54255 non-null  float64
#  52  2008            53878 non-null  float64
#  53  2009            54437 non-null  float64
#  54  2010            57099 non-null  float64
#  55  2011            54922 non-null  float64
#  56  2012            54927 non-null  float64
#  57  2013            52924 non-null  float64
#  58  2014            52199 non-null  float64
#  59  2015            43068 non-null  float64
#  60  Unnamed: 60     0 non-null      float64
# dtypes: float64(57), object(4)
# memory usage: 41.4+ MB

# %% [markdown]
# <br></br>
# <br></br>
# That last column doesn't have anything in it, so we'll drop it.

# %%
df.drop(columns=['Unnamed: 60'], inplace=True)

# %% [markdown]
# <br></br>
# <br></br>
# Also we are starting to see that we have a high occurrence of _NaN_ values in this data.
#
# Use `.count()` to check the number of non-null values, and `.isna()` to check the nulls.  Use `.sum()` to add them:

# %%
nans = df.isna().sum().sum()
non_nas = df.count().sum().sum()
total = nans + non_nas

print(f'{nans} NaNs in {total} total values, or {round(nans / total * 100, 2)}% NaN')
# Out:
# 2508518 NaNs in 5340600 total values, or 46.97% NaN

# %% [markdown]
# <br></br>
# <br></br>
# **_That's a lot of missing values!  Next..._**
# <br></br>
# <br></br>
# Use `.iloc[:, :]` and `.drop_duplicates()` to analyze the unique values in the **Incidator Name** & **Indicator Code** columns.
#
# Use `.sort_values()` and `.reset_index()` to sort data in alphabetical order & add a new index.  The old index values will become a new column - use `.drop()` to get rid of it.
#
# Use `inplace=True` parameter to manipulate the DataFrame in place (not return a copy) where available.

# %%
indicators = df.iloc[:, 2:4]
indicators.drop_duplicates(inplace=True)
indicators.sort_values(by=['Indicator Name'], inplace=True)
indicators.reset_index(inplace=True)
indicators.drop(columns=['index'], inplace=True)
indicators
# Out:
#                                         Indicator Name     Indicator Code
# 0    % of females ages 15-49 having comprehensive c...  SH.HIV.KNOW.FE.ZS
# 1    % of males ages 15-49 having comprehensive cor...  SH.HIV.KNOW.MA.ZS
# 2             AIDS estimated deaths (UNAIDS estimates)     SH.DYN.AIDS.DH
# 3    ARI treatment (% of children under 5 taken to ...     SH.STA.ARIC.ZS
# 4    Adolescent fertility rate (births per 1,000 wo...        SP.ADO.TFRT
# ..                                                 ...                ...
# 340  Use of any antimalarial drug (% of pregnant wo...     SH.MLR.PREG.ZS
# 341  Use of insecticide-treated bed nets (% of unde...     SH.MLR.NETS.ZS
# 342  Vitamin A supplementation coverage rate (% of ...     SN.ITK.VITA.ZS
# 343           Wanted fertility rate (births per woman)        SP.DYN.WFRT
# 344  Women's share of population ages 15+ living wi...  SH.DYN.AIDS.FE.ZS
#
# [345 rows x 2 columns]

# %% [markdown]
# <br></br>
# <br></br>
# **_NOTE:_** Better practice to use `.loc` for indexing when possible...
#
# Use `.loc[:, :]` to refer by **row index** and / or **column name** instead of integer reference (`.iloc`).  (see next cell)

# %% [markdown]
# <br></br>
# Analyze the unique values in the **Country Name** & **Country Code** columns, same as we did the Indicators above:
# <br></br>

# %%
regions = df.loc[:, 'Country Name':'Country Code']
regions.drop_duplicates(inplace=True)
regions.sort_values(by=['Country Name'], inplace=True)
regions.reset_index(inplace=True)
regions.drop(columns=['index'], inplace=True)
regions
# Out:
#            Country Name Country Code
# 0           Afghanistan          AFG
# 1               Albania          ALB
# 2               Algeria          DZA
# 3        American Samoa          ASM
# 4               Andorra          ADO
# ..                  ...          ...
# 253  West Bank and Gaza          WBG
# 254               World          WLD
# 255         Yemen, Rep.          YEM
# 256              Zambia          ZMB
# 257            Zimbabwe          ZWE
#
# [258 rows x 2 columns]

# %% [markdown]
# <br></br>
# ### Let's drill down now into some of the different groups & indicators:

# %%
# Function to create a dataframe with all INDICATORS for a single COUNTRY
# Sort and organize it a bit.  Transpose to get the years as rows.
def data_by_country(country):
    df_country = df.copy()
    df_country = df_country[df_country['Country Name'] == country]
    df_country.sort_values(by=['Indicator Name'], inplace=True)
    df_country.rename(columns={'Indicator Name': country}, inplace=True)
    df_country.set_index(country, inplace=True)
    df_country = df_country.transpose(copy=True)
    df_country.drop(index=['Country Code', 'Indicator Code', 'Country Name'], inplace=True)
    return df_country


# Same function, but creates a dataframe with all COUNTRIES for a single INDICATOR
def data_by_indicator(indicator_name):
    df_indicator = df.copy()
    df_indicator = df_indicator[df_indicator['Indicator Name'] == indicator_name]
    df_indicator.sort_values(by=['Country Name'], inplace=True)
    df_indicator.rename(columns={'Country Name': indicator_name}, inplace=True)
    df_indicator.set_index(indicator_name, inplace=True)
    df_indicator = df_indicator.transpose(copy=True)
    df_indicator.drop(index=['Country Code', 'Indicator Code', 'Indicator Name'], inplace=True)
    return df_indicator

# %%
df_AFG = data_by_country('Afghanistan')
df_AFG.head()
# Out:
# Afghanistan % of females ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan % of males ages 15-49 having comprehensive correct knowledge about HIV (2 prevent ways and reject 3 misconceptions)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan AIDS estimated deaths (UNAIDS estimates)  \
# 1960                                             NaN
# 1961                                             NaN
# 1962                                             NaN
# 1963                                             NaN
# 1964                                             NaN
#
# Afghanistan ARI treatment (% of children under 5 taken to a health provider)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 1960                                                   145.321
# 1961                                                   145.321
# 1962                                                   145.321
# 1963                                                   145.321
# 1964                                                   145.321
#
# Afghanistan Adults (ages 15+) and children (0-14 years) living with HIV  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Adults (ages 15+) and children (ages 0-14) newly infected with HIV  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Adults (ages 15+) living with HIV  \
# 1960                                      NaN
# 1961                                      NaN
# 1962                                      NaN
# 1963                                      NaN
# 1964                                      NaN
#
# Afghanistan Adults (ages 15+) newly infected with HIV  \
# 1960                                              NaN
# 1961                                              NaN
# 1962                                              NaN
# 1963                                              NaN
# 1964                                              NaN
#
# Afghanistan Age at first marriage, female  ... Urban population  \
# 1960                                  NaN  ...           739462
# 1961                                  NaN  ...           779754
# 1962                                  NaN  ...           822719
# 1963                                  NaN  ...           868325
# 1964                                  NaN  ...           917022
#
# Afghanistan Urban population (% of total) Urban population growth (annual %)  \
# 1960                                8.221                            5.25381
# 1961                                8.508                            5.30556
# 1962                                8.805                            5.36362
# 1963                                 9.11                            5.39514
# 1964                                9.426                            5.45654
#
# Afghanistan Urban poverty headcount ratio at national poverty lines (% of urban population)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Use of Intermittent Preventive Treatment of malaria, 2+ doses of SP/Fansidar (% of pregnant women)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Use of any antimalarial drug (% of pregnant women)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Use of insecticide-treated bed nets (% of under-5 population)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Vitamin A supplementation coverage rate (% of children ages 6-59 months)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# Afghanistan Wanted fertility rate (births per woman)  \
# 1960                                             NaN
# 1961                                             NaN
# 1962                                             NaN
# 1963                                             NaN
# 1964                                             NaN
#
# Afghanistan Women's share of population ages 15+ living with HIV (%)
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# [5 rows x 345 columns]

# %%
df_AIDS_deaths = data_by_indicator('AIDS estimated deaths (UNAIDS estimates)')
df_AIDS_deaths.head()
# Out:
# AIDS estimated deaths (UNAIDS estimates) Afghanistan Albania Algeria  \
# 1960                                             NaN     NaN     NaN
# 1961                                             NaN     NaN     NaN
# 1962                                             NaN     NaN     NaN
# 1963                                             NaN     NaN     NaN
# 1964                                             NaN     NaN     NaN
#
# AIDS estimated deaths (UNAIDS estimates) American Samoa Andorra Angola  \
# 1960                                                NaN     NaN    NaN
# 1961                                                NaN     NaN    NaN
# 1962                                                NaN     NaN    NaN
# 1963                                                NaN     NaN    NaN
# 1964                                                NaN     NaN    NaN
#
# AIDS estimated deaths (UNAIDS estimates) Antigua and Barbuda Arab World  \
# 1960                                                     NaN        NaN
# 1961                                                     NaN        NaN
# 1962                                                     NaN        NaN
# 1963                                                     NaN        NaN
# 1964                                                     NaN        NaN
#
# AIDS estimated deaths (UNAIDS estimates) Argentina Armenia  ... Uzbekistan  \
# 1960                                           NaN     NaN  ...        NaN
# 1961                                           NaN     NaN  ...        NaN
# 1962                                           NaN     NaN  ...        NaN
# 1963                                           NaN     NaN  ...        NaN
# 1964                                           NaN     NaN  ...        NaN
#
# AIDS estimated deaths (UNAIDS estimates) Vanuatu Venezuela, RB Vietnam  \
# 1960                                         NaN           NaN     NaN
# 1961                                         NaN           NaN     NaN
# 1962                                         NaN           NaN     NaN
# 1963                                         NaN           NaN     NaN
# 1964                                         NaN           NaN     NaN
#
# AIDS estimated deaths (UNAIDS estimates) Virgin Islands (U.S.)  \
# 1960                                                       NaN
# 1961                                                       NaN
# 1962                                                       NaN
# 1963                                                       NaN
# 1964                                                       NaN
#
# AIDS estimated deaths (UNAIDS estimates) West Bank and Gaza World Yemen, Rep.  \
# 1960                                                    NaN   NaN         NaN
# 1961                                                    NaN   NaN         NaN
# 1962                                                    NaN   NaN         NaN
# 1963                                                    NaN   NaN         NaN
# 1964                                                    NaN   NaN         NaN
#
# AIDS estimated deaths (UNAIDS estimates) Zambia Zimbabwe
# 1960                                        NaN      NaN
# 1961                                        NaN      NaN
# 1962                                        NaN      NaN
# 1963                                        NaN      NaN
# 1964                                        NaN      NaN
#
# [5 rows x 258 columns]

# %%
df_AFG.count().sum()
# Out:
# 11414

# %%
fig, ax = plt.subplots(figsize=(12,6))

barheights = [x for x in df_AFG.count() > 25]
barlabels = df_AFG.columns

ax.bar(range(len(barheights)), barheights)
ax.set_xticks(range(len(barheights)))
ax.set_title('Afghanistan')
ax.set_xticklabels(barlabels, rotation=45);
